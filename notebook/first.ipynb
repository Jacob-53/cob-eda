# %%
from president_speech.db.parquet_interpreter import read_parquet, get_parquet_full_path

# %%
get_parquet_full_path()
# Out:
# '/home/jacob/code/cob-eda/.venv/lib/python3.10/site-packages/president_speech/db/parquet/president_speech_ko.parquet'

# %%
data_path = get_parquet_full_path()

# %%
import pandas as pd

# %%
df = pd.read_parquet(data_path)

# %%
df.head(3)
# Out:
#       division_number president                title        date location  \
# 5368          1305368       박정희  제5대 대통령 취임식 대통령 취임사  1963.12.17       국내
# 5369          1305369       박정희            국회 개회식 치사  1963.12.17       국내
# 5370          1305370       박정희               신년 메시지  1964.01.01       국내
#
#      kind                                        speech_text
# 5368  취임사  \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
# 5369  기념사   존경하는 국회의장, 의원제위 그리고 내외귀빈 여러분! 오늘 이 뜻깊은 제3공화국의...
# 5370  신년사   친애하는 국내외의 동포 여러분! 혁명의 고된 시련을 겪고 민정이양으로 매듭을 지은...

# %%
df.tail()
# Out:
#         division_number president      title        date location kind  \
# 102587          1401987       문재인   수석·보좌관회의  2021.04.05       국내   회의
# 102588          1401988       문재인  제16회 국무회의  2021.04.13       국내   회의
# 102589          1401989       문재인   수석·보좌관회의  2021.04.19       국내   회의
# 102590          1401990       문재인   수석·보좌관회의  2021.04.26       국내   회의
# 102591          1401991       문재인  제18회 국무회의  2021.04.27       국내   회의
#
#                                               speech_text
# 102587  우리가 코로나19 이전으로 얼마나 빨리 돌아갈 수 있는지 여부는 오로지 방역과 백신...
# 102588  정부는 국민께 무한책임을 진다는 자세로 흔들림 없이 국정에 임해야 합니다.방역도, ...
# 102589  우리 정부 임기 마지막 날까지 흔들림 없이 국민과 역사가 부여한 책무를 다하자는 다...
# 102590  코로나19와 같은 감염병의 세계적 대유행은 어느 한 나라가 자국의 문제를 해결한다고...
# 102591  오늘 한국은행이 발표한 1분기 GDP 속보치에 따르면 우리 경제는 올해 1분기에 이...

# %%
df.index
# Out:
# Index([  5368,   5369,   5370,   5371,   5372,   5373,   5374,   5375,   5376,
#          5377,
#        ...
#        102582, 102583, 102584, 102585, 102586, 102587, 102588, 102589, 102590,
#        102591],
#       dtype='int64', length=8771)

# %%
df.values[1:3]
# Out:
# array([[1305369, '박정희', '국회 개회식 치사', '1963.12.17', '국내', '기념사',
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['division_number', 'president', 'title', 'date', 'location', 'kind',
#        'speech_text'],
#       dtype='object')

# %%
df.describe()
# Out:
#        division_number
# count     8.771000e+03
# mean      1.330350e+06
# std       3.749870e+04
# min       1.305368e+06
# 25%       1.307560e+06
# 50%       1.309753e+06
# 75%       1.330362e+06
# max       1.401991e+06

# %%
df.T
# Out:
#                                                             5368    \
# division_number                                            1305368
# president                                                      박정희
# title                                          제5대 대통령 취임식 대통령 취임사
# date                                                    1963.12.17
# location                                                        국내
# kind                                                           취임사
# speech_text      \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
#
#                                                             5369    \
# division_number                                            1305369
# president                                                      박정희
# title                                                    국회 개회식 치사
# date                                                    1963.12.17
# location                                                        국내
# ...

# %%
df.sort_values(by='president').head(3)
# Out:
#       division_number president  \
# 8763          1308731       김대중
# 8941          1308909       김대중
# 8942          1308910       김대중
#
#                                               title        date location kind  \
# 8763    새천년준비위원 위촉장 수여 및 오찬 말씀(새천년에 가장 중요한 것은 의식개혁)  1999.04.12       국내  기념사
# 8941          제78회 어린이날 축하 메시지(꿈을 가진 사람만이 내일을 만듭니다)  2000.05.05       국내  기념사
# 8942  알레만 니카라과 대통령 내외를 위한 만찬연설(니카라과는 새천년 공동번영의 동반자)  2000.05.15       국내  환영사
#
#                                             speech_text
# 8763  여러분께서 이번에 새천년을 앞두고 우리의 운명을 생각하는 막중한 대임을 맡게 되었습...
# 8941  사랑하는 어린이 여러분 일흔여덟번째 어린이날을 축하합니다. 오늘은 새천년의 첫 번째...
# 8942  알레만 니카라과 대통령 각하 내외분,그리고 내외 귀빈 여러분! 먼 여로를 마다치 않...

# %%
df.dtypes
# Out:
# division_number     int64
# president          object
# title              object
# date               object
# location           object
# kind               object
# speech_text        object
# dtype: object

# %%
df['president'].head(5)
# Out:
# 5368    박정희
# 5369    박정희
# 5370    박정희
# 5371    박정희
# 5372    박정희
# Name: president, dtype: object

# %%
df[0:3]
# Out:
#       division_number president                title        date location  \
# 5368          1305368       박정희  제5대 대통령 취임식 대통령 취임사  1963.12.17       국내
# 5369          1305369       박정희            국회 개회식 치사  1963.12.17       국내
# 5370          1305370       박정희               신년 메시지  1964.01.01       국내
#
#      kind                                        speech_text
# 5368  취임사  \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
# 5369  기념사   존경하는 국회의장, 의원제위 그리고 내외귀빈 여러분! 오늘 이 뜻깊은 제3공화국의...
# 5370  신년사   친애하는 국내외의 동포 여러분! 혁명의 고된 시련을 겪고 민정이양으로 매듭을 지은...

# %% [markdown]
# ### 첫 줄 출력

# %%
df.iloc[0]
# Out:
# division_number                                              1305368
# president                                                        박정희
# title                                            제5대 대통령 취임식 대통령 취임사
# date                                                      1963.12.17
# location                                                          국내
# kind                                                             취임사
# speech_text        \n\n\n단군성조가 천혜의 이 강토 위에 국기를 닦으신지 반만년, 연면히 이어온 ...
# Name: 5368, dtype: object

# %%
df.iloc[0,0:2]
# Out:
# division_number    1305368
# president              박정희
# Name: 5368, dtype: object

# %%
df.iloc[0:2,0:2]
# Out:
#       division_number president
# 5368          1305368       박정희
# 5369          1305369       박정희

# %%
### 숫자로 특정한곳 값 뽑을때

# %%
df.iat[0,0]
# Out:
# 1305368

# %%
df.iat[0,1]
# Out:
# '박정희'

# %%
### 필터링 걸어서 조회 첫 2

# %%
df[df.president == "김대중"].head(2)
# Out:
#       division_number president                             title        date  \
# 8557          1308525       김대중  제15 대통령 취임사(국난극복과 재도약의 새시대를 엽시다)  1998.02.25
# 8558          1308526       김대중   대통령 취임 경축 만찬 연설(위기극복에 다함께 나섭시다)  1998.02.25
#
#      location kind                                        speech_text
# 8557       국내  취임사  \r\n \r\n존경하고 사랑하는 국민 여러분! \n\r\n오늘 저는 대한민국 제1...
# 8558       국내  환영사  존경하는 내외 국민 여러분!\r\n \r\n 다시 한번 여러분의 축하에 감사드립니다...

# %%
### 여러개 조건으로 필터 적용

# %%
df[df['president'].isin(['노무현','문재인'])]
# Out:
#         division_number president                      title        date  \
# 9379            1309347       노무현              제16 대 대통령 취임사  2003.02.25
# 9380            1309348       노무현        제16 대 대통령 취임 경축연 연설  2003.02.25
# 9381            1309349       노무현   제16 대통령 취임 축하 외빈을 위한 만찬사  2003.02.25
# 9382            1309350       노무현  학군사관후보생(ROTC) 제41기 임관식 치사  2003.02.28
# 9383            1309351       노무현        2·28민주의거 43주년 기념메시지  2003.02.28
# ...                 ...       ...                        ...         ...
# 102587          1401987       문재인                   수석·보좌관회의  2021.04.05
# 102588          1401988       문재인                  제16회 국무회의  2021.04.13
# 102589          1401989       문재인                   수석·보좌관회의  2021.04.19
# 102590          1401990       문재인                   수석·보좌관회의  2021.04.26
# 102591          1401991       문재인                  제18회 국무회의  2021.04.27
#
#        location kind                                        speech_text
# ...

# %%
### 스피치 내용 중 '자유'가 들어가는 row  필터링

# %%
df[df['speech_text'].str.contains("자유")]
# Out:
#         division_number president                title        date location  \
# 5368            1305368       박정희  제5대 대통령 취임식 대통령 취임사  1963.12.17       국내
# 5374            1305374       박정희       1964년 대통령 연두교서  1964.01.10       국내
# 5375            1305375       박정희  자유의 날 10주년에 즈음한 메시지  1964.01.23       국내
# 5377            1305377       박정희        제45회 3·1절 경축사  1964.03.01       국내
# 5379            1305379       박정희      한·일회담에 관한 특별담화문  1964.03.26       국내
# ...                 ...       ...                  ...         ...      ...
# 102534          1401934       문재인        제74주년 광복절 경축사  2019.08.15       국내
# 102535          1401935       문재인      제74차 유엔 총회 기조연설  2019.09.24       국내
# 102546          1401946       문재인            제37회 국무회의  2020.07.21       국내
# 102550          1401950       문재인             수석·보좌관회의  2020.08.24       국내
# 102556          1401956       문재인            제48회 국무회의  2020.09.22       국내
#
# ...

# %%
### 스피치 내용 중 '자유'가 들어가는 row  필터링 대소문자 구분안한다는 조건
### https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html#pandas.Series.str.contains

# %%
df[df['speech_text'].str.contains("ioc",case=False)]
# Out:
#         division_number president  \
# 7139            1307107       전두환
# 7503            1307471       노태우
# 8513            1308481       김영삼
# 8557            1308525       김대중
# 8802            1308770       김대중
# 8999            1308967       김대중
# 9371            1309339       김대중
# 9901            1309869       노무현
# 10001           1309969       노무현
# 10004           1309972       노무현
# 10089           1310057       노무현
# 10283           1310251       이명박
# 30013           1329981       이명박
# 30485           1330453       이명박
# 30572           1330540       이명박
# 101310          1400711       문재인
# 101544          1400945       문재인
# 101612          1401013       문재인
# 101698          1401099       문재인
# 102261          1401662       문재인
# 102281          1401682       문재인
# 102316          1401716       문재인
# 102330          1401730       문재인
# 102370          1401770       문재인
# 102372          1401772       문재인
# 102397          1401797       문재인
# ...

# %%
f_df = df[df['speech_text'].str.contains("올림픽",case=False)]

# %%
### 대통령별 '올림픽' 발언 횟수

# %%
f_df.groupby("president").size()
# Out:
# president
# 김대중     40
# 김영삼     32
# 노무현     32
# 노태우    292
# 문재인    161
# 박근혜     14
# 박정희     29
# 이명박    107
# 전두환    165
# 최규하      2
# dtype: int64

# %%
### rdf 로 변수지정

# %%
rdf=f_df.groupby("president").size().reset_index(name='count')

# %%
print(rdf)
# Out:
#   president  count
# 0       김대중     40
# 1       김영삼     32
# 2       노무현     32
# 3       노태우    292
# 4       문재인    161
# 5       박근혜     14
# 6       박정희     29
# 7       이명박    107
# 8       전두환    165
# 9       최규하      2

# %%
# 타입확인

# %%
type(f_df.groupby("president").size())
# Out:
# pandas.core.series.Series

# %%
rdf.sort_values(by='count',ascending=False)
# Out:
#   president  count
# 3       노태우    292
# 8       전두환    165
# 4       문재인    161
# 7       이명박    107
# 0       김대중     40
# 1       김영삼     32
# 2       노무현     32
# 6       박정희     29
# 5       박근혜     14
# 9       최규하      2

# %%
presidents_speeche = { "박정희": 513,"이승만": 438,"노태우": 399,"김대중":     305,"문재인": 275,"김영삼": 274,"이명박": 262,"전두환": 242,"노무현": 230,"    박근혜": 111,"최규하": 14,"윤보선": 1 }
